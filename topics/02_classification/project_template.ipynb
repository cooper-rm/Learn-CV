# %% [markdown]
# # Image Classification Project
#
# **Title:** [Your project title]
#
# **Author:** [Your name]
#
# **Goal:** [What are you classifying?]
#
# ---

# %% [markdown]
# ## 1. Setup

# %%
# Import libraries and set device

# %% [markdown]
# ## 2. Data

# %%
# Load dataset

# %%
# Visualize samples

# %%
# Create data loaders

# %% [markdown]
# ## 3. Model

# %%
# Define or load model

# %% [markdown]
# ## 4. Training

# %%
# Define loss and optimizer

# %%
# Training loop

# %% [markdown]
# ## 5. Evaluation

# %%
# Plot training curves

# %%
# Confusion matrix

# %%
# Error analysis

# %% [markdown]
# ## 6. Save

# %%
# Save model

# %% [markdown]
# ## 7. Conclusions
#
# **Results:**
# - Train accuracy: ___
# - Val accuracy: ___
#
# **What worked:**
#
# **Future Iterations and Opportunities:**
